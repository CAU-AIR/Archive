# %% [markdown]
# ## Using CNN and NCM for CIFAR-10 feature extraction and classification
#
# ### Summary
# CIFAR-10 데이터셋을 분류하기 위해 CNN을 이용하여 데이터셋에 대한 특징을 추출 후 NCM을 이용하여 각 class에 대한 평균 값을 이용하여 분류
#
# <span style="color: #2D3748; background-color:#fff5b1;">Test size를 0.2로 10번 반복 실험한 결과 평균적으로 0.34의 정확도를 보여주고 있고, test 데이터 1개를 분류하는데 0.0011초의 시간이 걸린다.</span>

# %%
import time
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
from utils.util import Info
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torchvision.models import resnet18
from utils.Data_Classifier import train, validate

# %%
class Config(Info):
    def __init__(self):
        super(Info, self).__init__()
        self.device = 'PC'
        self.dataset = 'CIFAR_10'
        self.test_size = 0.2
        self.feature_size = 3072
        self.method = 'CNN'
        self.iter = 10

# %%
# cig = Config()
# cig.info()
# cig.print_rutin()

# %%
seed = 0
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# torch.cuda.manual_seed_all(seed) # if use multi-GPU
cudnn.deterministic = True  # 연산 처리 속도 감소 -> 모델과 코드를 배포해야 하는 연구 후반 단계에 사용
cudnn.benchmark = False

# %% [markdown]
# ## Load CIFAR-10 Dataset

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                ])

batch_size = 512

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

validationset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
val_loader = DataLoader(validationset, batch_size=batch_size, shuffle=False, num_workers=2)

print(trainset.data.shape)
print(validationset.data.shape)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

epoch = 100
num_class = 10

model = resnet18(num_classes=num_class)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# %%
best_acc = 0.

for idx in range(epoch):  # loop over the dataset multiple times
    # train for one epoch
    train(train_loader, model, criterion, optimizer, idx, device)

    # evaluate on validation set
    acc = validate(val_loader, model, criterion, device)

    # remember best acc@1 and save checkpoint
    is_best = acc > best_acc
    best_acc = max(acc, best_acc)

    scheduler.step()

print('Finished Training')
# Out:
# Epoch: [0]
# Train: [98/98]	Time 0.0484	Data 0.0225	Loss 2.1219	Acc 33.14
# Test: [20/20]	Time 0.0944	Data 0.0852	Loss 16.4620	Acc 39.76
# Epoch: [1]
# Train: [98/98]	Time 0.0491	Data 0.0227	Loss 1.5159	Acc 47.11
# Test: [20/20]	Time 0.0937	Data 0.0826	Loss 1.3771	Acc 51.05
# Epoch: [2]
# Train: [98/98]	Time 0.0501	Data 0.0232	Loss 1.3283	Acc 53.97
# Test: [20/20]	Time 0.0961	Data 0.0838	Loss 1.2378	Acc 55.38
# Epoch: [3]
# Train: [98/98]	Time 0.0482	Data 0.0226	Loss 1.1447	Acc 60.39
# Test: [20/20]	Time 0.0902	Data 0.0801	Loss 1.1518	Acc 59.36
# Epoch: [4]
# Train: [98/98]	Time 0.0488	Data 0.0227	Loss 1.0506	Acc 64.86
# Test: [20/20]	Time 0.0920	Data 0.0817	Loss 11.4038	Acc 48.03
# Epoch: [5]
# Train: [98/98]	Time 0.0501	Data 0.0233	Loss 0.9206	Acc 69.23
# Test: [20/20]	Time 0.0973	Data 0.0846	Loss 1.0033	Acc 66.22
# Epoch: [6]
# Train: [98/98]	Time 0.0502	Data 0.0233	Loss 0.7450	Acc 74.36
# Test: [20/20]	Time 0.0933	Data 0.0801	Loss 0.9484	Acc 68.70
# Epoch: [7]
# Train: [98/98]	Time 0.0501	Data 0.0232	Loss 0.6725	Acc 76.86
# Test: [20/20]	Time 0.0960	Data 0.0821	Loss 0.9261	Acc 68.66
# Epoch: [8]
# Train: [98/98]	Time 0.0464	Data 0.0219	Loss 0.5844	Acc 79.56
# Test: [20/20]	Time 0.0902	Data 0.0808	Loss 0.8827	Acc 70.68
# Epoch: [9]
# Train: [98/98]	Time 0.0471	Data 0.0221	Loss 0.4593	Acc 84.14
# Test: [20/20]	Time 0.0914	Data 0.0822	Loss 0.9209	Acc 70.51
# Epoch: [10]
# Train: [98/98]	Time 0.0470	Data 0.0219	Loss 0.4105	Acc 85.72
# Test: [20/20]	Time 0.0944	Data 0.0846	Loss 0.9855	Acc 71.07
# Epoch: [11]
# Train: [98/98]	Time 0.0475	Data 0.0222	Loss 0.3176	Acc 88.78
# Test: [20/20]	Time 0.0922	Data 0.0831	Loss 1.0382	Acc 70.37
# Epoch: [12]
# Train: [98/98]	Time 0.0465	Data 0.0215	Loss 0.2628	Acc 90.74
# Test: [20/20]	Time 0.0933	Data 0.0840	Loss 1.1093	Acc 70.18
# Epoch: [13]
# Train: [98/98]	Time 0.0484	Data 0.0224	Loss 0.2041	Acc 92.81
# Test: [20/20]	Time 0.0918	Data 0.0824	Loss 1.1906	Acc 70.82
# Epoch: [14]
# Train: [98/98]	Time 0.0487	Data 0.0232	Loss 0.1756	Acc 93.69
# Test: [20/20]	Time 0.0929	Data 0.0835	Loss 1.1605	Acc 71.71
# Epoch: [15]
# Train: [98/98]	Time 0.0484	Data 0.0230	Loss 0.1303	Acc 95.30
# Test: [20/20]	Time 0.0911	Data 0.0818	Loss 1.3825	Acc 71.60
# Epoch: [16]
# Train: [98/98]	Time 0.0472	Data 0.0222	Loss 0.1181	Acc 95.80
# Test: [20/20]	Time 0.0939	Data 0.0847	Loss 1.3753	Acc 71.32
# Epoch: [17]
# Train: [98/98]	Time 0.0491	Data 0.0229	Loss 0.1076	Acc 96.22
# Test: [20/20]	Time 0.0931	Data 0.0822	Loss 1.4223	Acc 70.75
# Epoch: [18]
# Train: [98/98]	Time 0.0485	Data 0.0226	Loss 0.0782	Acc 97.24
# Test: [20/20]	Time 0.0914	Data 0.0815	Loss 1.4714	Acc 71.55
# Epoch: [19]
# Train: [98/98]	Time 0.0485	Data 0.0222	Loss 0.0797	Acc 97.21
# Test: [20/20]	Time 0.0897	Data 0.0800	Loss 1.5083	Acc 71.46
# Epoch: [20]
# Train: [98/98]	Time 0.0483	Data 0.0218	Loss 0.0736	Acc 97.44
# Test: [20/20]	Time 0.0944	Data 0.0848	Loss 1.5276	Acc 71.75
# Epoch: [21]
# Train: [98/98]	Time 0.0487	Data 0.0223	Loss 0.0602	Acc 97.89
# Test: [20/20]	Time 0.0925	Data 0.0824	Loss 1.5950	Acc 71.78
# Epoch: [22]
# Train: [98/98]	Time 0.0489	Data 0.0223	Loss 0.0482	Acc 98.35
# Test: [20/20]	Time 0.0929	Data 0.0807	Loss 1.6111	Acc 71.89
# Epoch: [23]
# Train: [98/98]	Time 0.0494	Data 0.0228	Loss 0.0440	Acc 98.40
# Test: [20/20]	Time 0.0975	Data 0.0862	Loss 1.6963	Acc 72.00
# Epoch: [24]
# Train: [98/98]	Time 0.0482	Data 0.0224	Loss 0.0429	Acc 98.50
# Test: [20/20]	Time 0.0959	Data 0.0815	Loss 1.5965	Acc 71.93
# Epoch: [25]
# Train: [98/98]	Time 0.0493	Data 0.0230	Loss 0.0341	Acc 98.79
# Test: [20/20]	Time 0.0941	Data 0.0832	Loss 1.7589	Acc 72.12
# Epoch: [26]
# Train: [98/98]	Time 0.0483	Data 0.0221	Loss 0.0301	Acc 98.96
# Test: [20/20]	Time 0.0914	Data 0.0815	Loss 1.7444	Acc 72.81
# Epoch: [27]
# Train: [98/98]	Time 0.0487	Data 0.0223	Loss 0.0302	Acc 98.94
# Test: [20/20]	Time 0.0920	Data 0.0818	Loss 1.7274	Acc 72.57
# Epoch: [28]
# Train: [98/98]	Time 0.0485	Data 0.0224	Loss 0.0345	Acc 98.81
# Test: [20/20]	Time 0.0982	Data 0.0834	Loss 1.7802	Acc 72.57
# Epoch: [29]
# Train: [98/98]	Time 0.0495	Data 0.0230	Loss 0.0270	Acc 99.07
# Test: [20/20]	Time 0.0917	Data 0.0808	Loss 1.7934	Acc 72.70
# Epoch: [30]
# Train: [98/98]	Time 0.0486	Data 0.0219	Loss 0.0203	Acc 99.32
# Test: [20/20]	Time 0.0935	Data 0.0809	Loss 1.7668	Acc 73.20
# Epoch: [31]
# Train: [98/98]	Time 0.0474	Data 0.0226	Loss 0.0111	Acc 99.62
# Test: [20/20]	Time 0.0922	Data 0.0824	Loss 1.8926	Acc 73.13
# Epoch: [32]
# Train: [98/98]	Time 0.0482	Data 0.0220	Loss 0.0131	Acc 99.57
# Test: [20/20]	Time 0.0903	Data 0.0805	Loss 1.9225	Acc 73.19
# Epoch: [33]
# Train: [98/98]	Time 0.0482	Data 0.0223	Loss 0.0176	Acc 99.43
# Test: [20/20]	Time 0.0905	Data 0.0802	Loss 1.9184	Acc 72.91
# Epoch: [34]
# Train: [98/98]	Time 0.0477	Data 0.0231	Loss 0.0149	Acc 99.51
# Test: [20/20]	Time 0.0921	Data 0.0823	Loss 1.9275	Acc 73.37
# Epoch: [35]
# Train: [98/98]	Time 0.0492	Data 0.0228	Loss 0.0118	Acc 99.60
# Test: [20/20]	Time 0.0902	Data 0.0807	Loss 1.8890	Acc 73.26
# Epoch: [36]
# Train: [98/98]	Time 0.0490	Data 0.0223	Loss 0.0097	Acc 99.67
# Test: [20/20]	Time 0.0942	Data 0.0834	Loss 1.9712	Acc 73.96
# Epoch: [37]
# Train: [98/98]	Time 0.0484	Data 0.0222	Loss 0.0080	Acc 99.76
# Test: [20/20]	Time 0.0988	Data 0.0835	Loss 2.0127	Acc 73.52
# Epoch: [38]
# Train: [98/98]	Time 0.0501	Data 0.0228	Loss 0.0098	Acc 99.69
# Test: [20/20]	Time 0.0934	Data 0.0838	Loss 1.9803	Acc 73.86
# Epoch: [39]
# Train: [98/98]	Time 0.0481	Data 0.0224	Loss 0.0059	Acc 99.83
# Test: [20/20]	Time 0.0914	Data 0.0823	Loss 2.0136	Acc 73.84
# Epoch: [40]
# Train: [98/98]	Time 0.0479	Data 0.0217	Loss 0.0037	Acc 99.88
# Test: [20/20]	Time 0.0942	Data 0.0824	Loss 2.1202	Acc 74.02
# Epoch: [41]
# Train: [98/98]	Time 0.0484	Data 0.0222	Loss 0.0055	Acc 99.80
# Test: [20/20]	Time 0.0934	Data 0.0810	Loss 2.0742	Acc 73.48
# Epoch: [42]
# Train: [98/98]	Time 0.0482	Data 0.0223	Loss 0.0066	Acc 99.78
# Test: [20/20]	Time 0.0908	Data 0.0810	Loss 2.1080	Acc 73.10
# Epoch: [43]
# Train: [98/98]	Time 0.0483	Data 0.0228	Loss 0.0065	Acc 99.80
# Test: [20/20]	Time 0.0928	Data 0.0831	Loss 1.9640	Acc 74.13
# Epoch: [44]
# Train: [98/98]	Time 0.0489	Data 0.0228	Loss 0.0027	Acc 99.92
# Test: [20/20]	Time 0.0932	Data 0.0823	Loss 2.1109	Acc 73.85
# Epoch: [45]
# Train: [98/98]	Time 0.0483	Data 0.0220	Loss 0.0026	Acc 99.93
# Test: [20/20]	Time 0.0919	Data 0.0819	Loss 2.0426	Acc 74.53
# Epoch: [46]
# Train: [98/98]	Time 0.0490	Data 0.0225	Loss 0.0010	Acc 99.98
# Test: [20/20]	Time 0.0941	Data 0.0809	Loss 2.1136	Acc 74.40
# Epoch: [47]
# Train: [98/98]	Time 0.0485	Data 0.0228	Loss 0.0005	Acc 99.99
# Test: [20/20]	Time 0.0896	Data 0.0802	Loss 2.0854	Acc 74.42
# Epoch: [48]
# Train: [98/98]	Time 0.0482	Data 0.0219	Loss 0.0002	Acc 100.00
# Test: [20/20]	Time 0.0912	Data 0.0815	Loss 2.0752	Acc 74.73
# Epoch: [49]
# Train: [98/98]	Time 0.0473	Data 0.0217	Loss 0.0001	Acc 100.00
# Test: [20/20]	Time 0.0896	Data 0.0797	Loss 2.0800	Acc 74.75
# Epoch: [50]
# Train: [98/98]	Time 0.0484	Data 0.0220	Loss 0.0001	Acc 100.00
# Test: [20/20]	Time 0.0891	Data 0.0795	Loss 2.0656	Acc 74.69
# Epoch: [51]
# Train: [98/98]	Time 0.0485	Data 0.0221	Loss 0.0001	Acc 100.00
# Test: [20/20]	Time 0.0975	Data 0.0868	Loss 2.0744	Acc 74.64
# Epoch: [52]
# Train: [98/98]	Time 0.0501	Data 0.0227	Loss 0.0001	Acc 100.00
# Test: [20/20]	Time 0.0997	Data 0.0851	Loss 2.0659	Acc 74.71
# Epoch: [53]
# Train: [98/98]	Time 0.0495	Data 0.0231	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0937	Data 0.0802	Loss 2.0605	Acc 74.84
# Epoch: [54]
# Train: [98/98]	Time 0.0481	Data 0.0224	Loss 0.0001	Acc 100.00
# Test: [20/20]	Time 0.0902	Data 0.0804	Loss 2.0540	Acc 74.79
# Epoch: [55]
# Train: [98/98]	Time 0.0481	Data 0.0218	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0923	Data 0.0828	Loss 2.0502	Acc 74.70
# Epoch: [56]
# Train: [98/98]	Time 0.0490	Data 0.0224	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0889	Data 0.0793	Loss 2.0420	Acc 74.80
# Epoch: [57]
# Train: [98/98]	Time 0.0475	Data 0.0219	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0906	Data 0.0811	Loss 2.0438	Acc 74.84
# Epoch: [58]
# Train: [98/98]	Time 0.0474	Data 0.0217	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0905	Data 0.0795	Loss 2.0259	Acc 74.86
# Epoch: [59]
# Train: [98/98]	Time 0.0483	Data 0.0222	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0896	Data 0.0800	Loss 2.0074	Acc 74.84
# Epoch: [60]
# Train: [98/98]	Time 0.0482	Data 0.0218	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0911	Data 0.0813	Loss 2.0127	Acc 74.86
# Epoch: [61]
# Train: [98/98]	Time 0.0478	Data 0.0221	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0923	Data 0.0817	Loss 2.0153	Acc 74.90
# Epoch: [62]
# Train: [98/98]	Time 0.0491	Data 0.0227	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0896	Data 0.0798	Loss 2.0008	Acc 74.84
# Epoch: [63]
# Train: [98/98]	Time 0.0497	Data 0.0231	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0925	Data 0.0826	Loss 1.9956	Acc 74.88
# Epoch: [64]
# Train: [98/98]	Time 0.0487	Data 0.0225	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0908	Data 0.0809	Loss 2.0006	Acc 74.86
# Epoch: [65]
# Train: [98/98]	Time 0.0483	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0903	Data 0.0807	Loss 2.0022	Acc 74.86
# Epoch: [66]
# Train: [98/98]	Time 0.0479	Data 0.0221	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0914	Data 0.0816	Loss 1.9808	Acc 74.89
# Epoch: [67]
# Train: [98/98]	Time 0.0485	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0895	Data 0.0795	Loss 1.9729	Acc 74.88
# Epoch: [68]
# Train: [98/98]	Time 0.0486	Data 0.0222	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0904	Data 0.0803	Loss 1.9689	Acc 74.89
# Epoch: [69]
# Train: [98/98]	Time 0.0478	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0900	Data 0.0804	Loss 1.9762	Acc 74.85
# Epoch: [70]
# Train: [98/98]	Time 0.0480	Data 0.0217	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0881	Data 0.0784	Loss 1.9625	Acc 74.80
# Epoch: [71]
# Train: [98/98]	Time 0.0483	Data 0.0218	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0906	Data 0.0809	Loss 1.9584	Acc 74.86
# Epoch: [72]
# Train: [98/98]	Time 0.0481	Data 0.0218	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0892	Data 0.0794	Loss 1.9581	Acc 74.90
# Epoch: [73]
# Train: [98/98]	Time 0.0479	Data 0.0217	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0907	Data 0.0807	Loss 1.9646	Acc 74.96
# Epoch: [74]
# Train: [98/98]	Time 0.0472	Data 0.0216	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0905	Data 0.0808	Loss 1.9575	Acc 74.88
# Epoch: [75]
# Train: [98/98]	Time 0.0481	Data 0.0218	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0903	Data 0.0807	Loss 1.9359	Acc 74.93
# Epoch: [76]
# Train: [98/98]	Time 0.0477	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0894	Data 0.0799	Loss 1.9409	Acc 74.86
# Epoch: [77]
# Train: [98/98]	Time 0.0486	Data 0.0223	Loss 0.0001	Acc 100.00
# Test: [20/20]	Time 0.0902	Data 0.0805	Loss 1.9308	Acc 74.74
# Epoch: [78]
# Train: [98/98]	Time 0.0474	Data 0.0215	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0902	Data 0.0807	Loss 1.9518	Acc 74.96
# Epoch: [79]
# Train: [98/98]	Time 0.0483	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0899	Data 0.0802	Loss 1.9287	Acc 74.90
# Epoch: [80]
# Train: [98/98]	Time 0.0478	Data 0.0219	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0909	Data 0.0814	Loss 1.9417	Acc 74.87
# Epoch: [81]
# Train: [98/98]	Time 0.0483	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0887	Data 0.0790	Loss 1.9240	Acc 75.06
# Epoch: [82]
# Train: [98/98]	Time 0.0478	Data 0.0217	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0910	Data 0.0813	Loss 1.9406	Acc 75.02
# Epoch: [83]
# Train: [98/98]	Time 0.0482	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0901	Data 0.0805	Loss 1.9279	Acc 74.82
# Epoch: [84]
# Train: [98/98]	Time 0.0475	Data 0.0214	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0885	Data 0.0789	Loss 1.9415	Acc 74.98
# Epoch: [85]
# Train: [98/98]	Time 0.0475	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0897	Data 0.0798	Loss 1.9329	Acc 74.96
# Epoch: [86]
# Train: [98/98]	Time 0.0480	Data 0.0218	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0895	Data 0.0800	Loss 1.9284	Acc 74.82
# Epoch: [87]
# Train: [98/98]	Time 0.0481	Data 0.0219	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0909	Data 0.0812	Loss 1.9328	Acc 74.86
# Epoch: [88]
# Train: [98/98]	Time 0.0483	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0906	Data 0.0809	Loss 1.9304	Acc 74.90
# Epoch: [89]
# Train: [98/98]	Time 0.0476	Data 0.0221	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0905	Data 0.0804	Loss 1.9265	Acc 74.87
# Epoch: [90]
# Train: [98/98]	Time 0.0486	Data 0.0222	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0907	Data 0.0810	Loss 1.9147	Acc 74.87
# Epoch: [91]
# Train: [98/98]	Time 0.0472	Data 0.0215	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0890	Data 0.0794	Loss 1.9269	Acc 74.85
# Epoch: [92]
# Train: [98/98]	Time 0.0484	Data 0.0221	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0900	Data 0.0805	Loss 1.9268	Acc 74.93
# Epoch: [93]
# Train: [98/98]	Time 0.0477	Data 0.0218	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0901	Data 0.0804	Loss 1.9311	Acc 74.96
# Epoch: [94]
# Train: [98/98]	Time 0.0471	Data 0.0217	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0898	Data 0.0801	Loss 1.9324	Acc 74.93
# Epoch: [95]
# Train: [98/98]	Time 0.0484	Data 0.0223	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0884	Data 0.0789	Loss 1.9358	Acc 74.98
# Epoch: [96]
# Train: [98/98]	Time 0.0480	Data 0.0221	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0921	Data 0.0820	Loss 1.9306	Acc 74.85
# Epoch: [97]
# Train: [98/98]	Time 0.0485	Data 0.0222	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0896	Data 0.0799	Loss 1.9205	Acc 74.93
# Epoch: [98]
# Train: [98/98]	Time 0.0483	Data 0.0220	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0895	Data 0.0798	Loss 1.9208	Acc 74.77
# Epoch: [99]
# Train: [98/98]	Time 0.0480	Data 0.0217	Loss 0.0000	Acc 100.00
# Test: [20/20]	Time 0.0910	Data 0.0813	Loss 1.9128	Acc 74.93
# Finished Training

# %%
transform_train = transforms.Compose([transforms.RandomCrop(32, padding=4),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                      ])

transform_test = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
                                     ])

batch_size = 512

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)

validationset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
val_loader = DataLoader(validationset, batch_size=batch_size, shuffle=False, num_workers=2)

print(trainset.data.shape)
print(validationset.data.shape)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

epoch = 100
num_class = 10

model = resnet18(num_classes=num_class)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# %%
best_acc = 0.

for idx in range(epoch):  # loop over the dataset multiple times
    # train for one epoch
    train(train_loader, model, criterion, optimizer, idx, device)

    # evaluate on validation set
    acc = validate(val_loader, model, criterion, device)

    # remember best acc and save checkpoint
    is_best = acc > best_acc
    best_acc = max(acc, best_acc)

    scheduler.step()

print('Finished Training')
# Out:
# Epoch: [0]
# Train: [98/98]	Time 0.0492	Data 0.0238	Loss 2.2192	Acc 29.30
# Test: [20/20]	Time 0.0890	Data 0.0793	Loss 1.6696	Acc 39.29
# Epoch: [1]
# Train: [98/98]	Time 0.0483	Data 0.0221	Loss 1.5844	Acc 42.19
# Test: [20/20]	Time 0.0902	Data 0.0806	Loss 1.9801	Acc 48.06
# Epoch: [2]
# Train: [98/98]	Time 0.0479	Data 0.0244	Loss 1.4539	Acc 47.83
# Test: [20/20]	Time 0.0917	Data 0.0813	Loss 1.2942	Acc 53.01
# Epoch: [3]
# Train: [98/98]	Time 0.0483	Data 0.0231	Loss 1.2803	Acc 54.36
# Test: [20/20]	Time 0.0906	Data 0.0811	Loss 1.2948	Acc 53.27
# Epoch: [4]
# Train: [98/98]	Time 0.0484	Data 0.0240	Loss 1.1471	Acc 59.13
# Test: [20/20]	Time 0.0893	Data 0.0797	Loss 1.0677	Acc 62.38
# Epoch: [5]
# Train: [98/98]	Time 0.0481	Data 0.0247	Loss 1.0396	Acc 63.20
# Test: [20/20]	Time 0.0893	Data 0.0797	Loss 0.9929	Acc 65.09
# Epoch: [6]
# Train: [98/98]	Time 0.0487	Data 0.0232	Loss 0.9662	Acc 65.99
# Test: [20/20]	Time 0.0888	Data 0.0792	Loss 1.0136	Acc 64.74
# Epoch: [7]
# Train: [98/98]	Time 0.0477	Data 0.0233	Loss 0.9022	Acc 68.11
# Test: [20/20]	Time 0.0906	Data 0.0808	Loss 0.8536	Acc 69.66
# Epoch: [8]
# Train: [98/98]	Time 0.0484	Data 0.0221	Loss 0.8444	Acc 70.19
# Test: [20/20]	Time 0.0898	Data 0.0799	Loss 0.8729	Acc 69.31
# Epoch: [9]
# Train: [98/98]	Time 0.0490	Data 0.0242	Loss 0.8001	Acc 71.62
# Test: [20/20]	Time 0.0900	Data 0.0806	Loss 0.8419	Acc 70.61
# Epoch: [10]
# Train: [98/98]	Time 0.0477	Data 0.0248	Loss 0.7618	Acc 73.32
# Test: [20/20]	Time 0.0893	Data 0.0798	Loss 0.8846	Acc 70.02
# Epoch: [11]
# Train: [98/98]	Time 0.0482	Data 0.0238	Loss 0.7301	Acc 74.54
# Test: [20/20]	Time 0.0877	Data 0.0782	Loss 0.8028	Acc 72.49
# Epoch: [12]
# Train: [98/98]	Time 0.0483	Data 0.0236	Loss 0.7008	Acc 75.44
# Test: [20/20]	Time 0.0886	Data 0.0789	Loss 0.7725	Acc 73.58
# Epoch: [13]
# Train: [98/98]	Time 0.0483	Data 0.0225	Loss 0.6739	Acc 76.32
# Test: [20/20]	Time 0.0927	Data 0.0832	Loss 0.7950	Acc 72.49
# Epoch: [14]
# Train: [98/98]	Time 0.0477	Data 0.0230	Loss 0.6535	Acc 77.18
# Test: [20/20]	Time 0.0882	Data 0.0785	Loss 0.7485	Acc 75.00
# Epoch: [15]
# Train: [98/98]	Time 0.0485	Data 0.0225	Loss 0.6358	Acc 77.76
# Test: [20/20]	Time 0.0891	Data 0.0790	Loss 0.7801	Acc 73.23
# Epoch: [16]
# Train: [98/98]	Time 0.0482	Data 0.0236	Loss 0.6211	Acc 78.37
# Test: [20/20]	Time 0.0876	Data 0.0777	Loss 0.7385	Acc 74.81
# Epoch: [17]
# Train: [98/98]	Time 0.0486	Data 0.0221	Loss 0.6016	Acc 78.85
# Test: [20/20]	Time 0.0882	Data 0.0786	Loss 0.6883	Acc 76.53
# Epoch: [18]
# Train: [98/98]	Time 0.0482	Data 0.0242	Loss 0.5819	Acc 79.57
# Test: [20/20]	Time 0.0896	Data 0.0800	Loss 0.6775	Acc 76.72
# Epoch: [19]
# Train: [98/98]	Time 0.0480	Data 0.0221	Loss 0.5750	Acc 79.84
# Test: [20/20]	Time 0.0886	Data 0.0790	Loss 0.6985	Acc 76.25
# Epoch: [20]
# Train: [98/98]	Time 0.0483	Data 0.0251	Loss 0.5573	Acc 80.45
# Test: [20/20]	Time 0.0895	Data 0.0799	Loss 0.6827	Acc 76.45
# Epoch: [21]
# Train: [98/98]	Time 0.0488	Data 0.0226	Loss 0.5430	Acc 81.09
# Test: [20/20]	Time 0.0905	Data 0.0811	Loss 0.6219	Acc 78.97
# Epoch: [22]
# Train: [98/98]	Time 0.0486	Data 0.0224	Loss 0.5300	Acc 81.43
# Test: [20/20]	Time 0.0898	Data 0.0803	Loss 0.6554	Acc 77.89
# Epoch: [23]
# Train: [98/98]	Time 0.0480	Data 0.0240	Loss 0.5231	Acc 81.63
# Test: [20/20]	Time 0.0903	Data 0.0803	Loss 0.7141	Acc 76.08
# Epoch: [24]
# Train: [98/98]	Time 0.0484	Data 0.0234	Loss 0.5108	Acc 82.24
# Test: [20/20]	Time 0.0894	Data 0.0797	Loss 0.6445	Acc 77.38
# Epoch: [25]
# Train: [98/98]	Time 0.0488	Data 0.0223	Loss 0.5044	Acc 82.46
# Test: [20/20]	Time 0.0895	Data 0.0801	Loss 0.6534	Acc 78.12
# Epoch: [26]
# Train: [98/98]	Time 0.0481	Data 0.0244	Loss 0.5014	Acc 82.47
# Test: [20/20]	Time 0.0928	Data 0.0801	Loss 0.6941	Acc 76.76
# Epoch: [27]
# Train: [98/98]	Time 0.0482	Data 0.0244	Loss 0.4838	Acc 83.01
# Test: [20/20]	Time 0.0896	Data 0.0801	Loss 0.6525	Acc 77.95
# Epoch: [28]
# Train: [98/98]	Time 0.0486	Data 0.0237	Loss 0.4798	Acc 83.06
# Test: [20/20]	Time 0.0884	Data 0.0785	Loss 0.6188	Acc 79.13
# Epoch: [29]
# Train: [98/98]	Time 0.0476	Data 0.0218	Loss 0.4619	Acc 83.89
# Test: [20/20]	Time 0.0902	Data 0.0804	Loss 0.6070	Acc 79.91
# Epoch: [30]
# Train: [98/98]	Time 0.0484	Data 0.0231	Loss 0.4583	Acc 84.05
# Test: [20/20]	Time 0.0891	Data 0.0796	Loss 0.6355	Acc 79.06
# Epoch: [31]
# Train: [98/98]	Time 0.0479	Data 0.0222	Loss 0.4516	Acc 84.19
# Test: [20/20]	Time 0.0911	Data 0.0811	Loss 0.8444	Acc 72.38
# Epoch: [32]
# Train: [98/98]	Time 0.0483	Data 0.0227	Loss 0.4394	Acc 84.81
# Test: [20/20]	Time 0.0902	Data 0.0806	Loss 0.6479	Acc 78.34
# Epoch: [33]
# Train: [98/98]	Time 0.0475	Data 0.0223	Loss 0.4397	Acc 84.65
# Test: [20/20]	Time 0.0896	Data 0.0798	Loss 0.5971	Acc 79.96
# Epoch: [34]
# Train: [98/98]	Time 0.0484	Data 0.0232	Loss 0.4234	Acc 85.20
# Test: [20/20]	Time 0.0895	Data 0.0799	Loss 0.6117	Acc 79.69
# Epoch: [35]
# Train: [98/98]	Time 0.0481	Data 0.0235	Loss 0.4164	Acc 85.35
# Test: [20/20]	Time 0.0889	Data 0.0792	Loss 0.7052	Acc 77.05
# Epoch: [36]
# Train: [98/98]	Time 0.0484	Data 0.0224	Loss 0.4070	Acc 85.79
# Test: [20/20]	Time 0.0899	Data 0.0800	Loss 0.6002	Acc 80.42
# Epoch: [37]
# Train: [98/98]	Time 0.0479	Data 0.0239	Loss 0.4034	Acc 85.94
# Test: [20/20]	Time 0.0904	Data 0.0808	Loss 0.5511	Acc 81.31
# Epoch: [38]
# Train: [98/98]	Time 0.0481	Data 0.0223	Loss 0.4022	Acc 85.85
# Test: [20/20]	Time 0.0917	Data 0.0820	Loss 0.5939	Acc 80.50
# Epoch: [39]
# Train: [98/98]	Time 0.0476	Data 0.0242	Loss 0.3886	Acc 86.14
# Test: [20/20]	Time 0.0887	Data 0.0791	Loss 0.6692	Acc 78.26
# Epoch: [40]
# Train: [98/98]	Time 0.0473	Data 0.0227	Loss 0.3753	Acc 86.87
# Test: [20/20]	Time 0.0910	Data 0.0811	Loss 0.6027	Acc 80.43
# Epoch: [41]
# Train: [98/98]	Time 0.0485	Data 0.0238	Loss 0.3774	Acc 86.69
# Test: [20/20]	Time 0.0875	Data 0.0779	Loss 0.5443	Acc 81.58
# Epoch: [42]
# Train: [98/98]	Time 0.0480	Data 0.0242	Loss 0.3693	Acc 87.00
# Test: [20/20]	Time 0.0882	Data 0.0787	Loss 0.6070	Acc 80.32
# Epoch: [43]
# Train: [98/98]	Time 0.0489	Data 0.0235	Loss 0.3573	Acc 87.57
# Test: [20/20]	Time 0.0909	Data 0.0812	Loss 0.5806	Acc 80.50
# Epoch: [44]
# Train: [98/98]	Time 0.0486	Data 0.0232	Loss 0.3556	Acc 87.50
# Test: [20/20]	Time 0.0895	Data 0.0799	Loss 0.6031	Acc 81.20
# Epoch: [45]
# Train: [98/98]	Time 0.0479	Data 0.0222	Loss 0.3528	Acc 87.71
# Test: [20/20]	Time 0.0888	Data 0.0791	Loss 0.5745	Acc 81.57
# Epoch: [46]
# Train: [98/98]	Time 0.0487	Data 0.0222	Loss 0.3348	Acc 88.38
# Test: [20/20]	Time 0.0890	Data 0.0791	Loss 0.5770	Acc 81.57
# Epoch: [47]
# Train: [98/98]	Time 0.0477	Data 0.0219	Loss 0.3337	Acc 88.47
# Test: [20/20]	Time 0.0890	Data 0.0795	Loss 0.5603	Acc 81.91
# Epoch: [48]
# Train: [98/98]	Time 0.0487	Data 0.0239	Loss 0.3216	Acc 88.70
# Test: [20/20]	Time 0.0892	Data 0.0796	Loss 0.5625	Acc 82.31
# Epoch: [49]
# Train: [98/98]	Time 0.0480	Data 0.0227	Loss 0.3123	Acc 88.99
# Test: [20/20]	Time 0.0924	Data 0.0820	Loss 0.5541	Acc 82.57
# Epoch: [50]
# Train: [98/98]	Time 0.0485	Data 0.0227	Loss 0.3079	Acc 89.15
# Test: [20/20]	Time 0.0881	Data 0.0784	Loss 0.5420	Acc 82.65
# Epoch: [51]
# Train: [98/98]	Time 0.0488	Data 0.0231	Loss 0.3023	Acc 89.29
# Test: [20/20]	Time 0.0907	Data 0.0811	Loss 0.5526	Acc 82.59
# Epoch: [52]
# Train: [98/98]	Time 0.0492	Data 0.0227	Loss 0.2981	Acc 89.64
# Test: [20/20]	Time 0.0906	Data 0.0807	Loss 0.5279	Acc 83.13
# Epoch: [53]
# Train: [98/98]	Time 0.0484	Data 0.0230	Loss 0.2852	Acc 89.83
# Test: [20/20]	Time 0.0907	Data 0.0811	Loss 0.5361	Acc 82.92
# Epoch: [54]
# Train: [98/98]	Time 0.0480	Data 0.0232	Loss 0.2837	Acc 90.10
# Test: [20/20]	Time 0.0891	Data 0.0794	Loss 0.5398	Acc 82.82
# Epoch: [55]
# Train: [98/98]	Time 0.0485	Data 0.0242	Loss 0.2661	Acc 90.64
# Test: [20/20]	Time 0.0921	Data 0.0825	Loss 0.5451	Acc 82.68
# Epoch: [56]
# Train: [98/98]	Time 0.0485	Data 0.0237	Loss 0.2651	Acc 90.72
# Test: [20/20]	Time 0.0891	Data 0.0794	Loss 0.5169	Acc 83.99
# Epoch: [57]
# Train: [98/98]	Time 0.0479	Data 0.0219	Loss 0.2534	Acc 91.13
# Test: [20/20]	Time 0.0888	Data 0.0789	Loss 0.5551	Acc 82.97
# Epoch: [58]
# Train: [98/98]	Time 0.0473	Data 0.0227	Loss 0.2540	Acc 90.92
# Test: [20/20]	Time 0.0915	Data 0.0816	Loss 0.5481	Acc 83.12
# Epoch: [59]
# Train: [98/98]	Time 0.0485	Data 0.0227	Loss 0.2458	Acc 91.34
# Test: [20/20]	Time 0.0900	Data 0.0804	Loss 0.5204	Acc 83.82
# Epoch: [60]
# Train: [98/98]	Time 0.0483	Data 0.0221	Loss 0.2301	Acc 91.95
# Test: [20/20]	Time 0.0895	Data 0.0799	Loss 0.5216	Acc 83.99
# Epoch: [61]
# Train: [98/98]	Time 0.0480	Data 0.0219	Loss 0.2221	Acc 92.11
# Test: [20/20]	Time 0.0900	Data 0.0803	Loss 0.5459	Acc 83.23
# Epoch: [62]
# Train: [98/98]	Time 0.0483	Data 0.0232	Loss 0.2165	Acc 92.39
# Test: [20/20]	Time 0.0900	Data 0.0804	Loss 0.5478	Acc 83.68
# Epoch: [63]
# Train: [98/98]	Time 0.0477	Data 0.0217	Loss 0.2032	Acc 92.77
# Test: [20/20]	Time 0.0893	Data 0.0796	Loss 0.5832	Acc 82.76
# Epoch: [64]
# Train: [98/98]	Time 0.0486	Data 0.0223	Loss 0.2076	Acc 92.56
# Test: [20/20]	Time 0.0885	Data 0.0788	Loss 0.5871	Acc 82.95
# Epoch: [65]
# Train: [98/98]	Time 0.0481	Data 0.0221	Loss 0.1963	Acc 93.11
# Test: [20/20]	Time 0.0912	Data 0.0814	Loss 0.5319	Acc 83.85
# Epoch: [66]
# Train: [98/98]	Time 0.0483	Data 0.0218	Loss 0.1839	Acc 93.59
# Test: [20/20]	Time 0.0905	Data 0.0810	Loss 0.5566	Acc 84.13
# Epoch: [67]
# Train: [98/98]	Time 0.0474	Data 0.0222	Loss 0.1751	Acc 93.86
# Test: [20/20]	Time 0.0879	Data 0.0783	Loss 0.5661	Acc 83.98
# Epoch: [68]
# Train: [98/98]	Time 0.0485	Data 0.0231	Loss 0.1697	Acc 93.93
# Test: [20/20]	Time 0.0892	Data 0.0799	Loss 0.5873	Acc 83.11
# Epoch: [69]
# Train: [98/98]	Time 0.0482	Data 0.0242	Loss 0.1627	Acc 94.23
# Test: [20/20]	Time 0.0902	Data 0.0805	Loss 0.5602	Acc 84.22
# Epoch: [70]
# Train: [98/98]	Time 0.0479	Data 0.0217	Loss 0.1572	Acc 94.30
# Test: [20/20]	Time 0.0904	Data 0.0808	Loss 0.5513	Acc 84.74
# Epoch: [71]
# Train: [98/98]	Time 0.0478	Data 0.0221	Loss 0.1445	Acc 94.84
# Test: [20/20]	Time 0.0898	Data 0.0802	Loss 0.5498	Acc 84.53
# Epoch: [72]
# Train: [98/98]	Time 0.0487	Data 0.0224	Loss 0.1369	Acc 95.15
# Test: [20/20]	Time 0.0899	Data 0.0805	Loss 0.5421	Acc 85.20
# Epoch: [73]
# Train: [98/98]	Time 0.0477	Data 0.0224	Loss 0.1303	Acc 95.44
# Test: [20/20]	Time 0.0912	Data 0.0813	Loss 0.5568	Acc 84.80
# Epoch: [74]
# Train: [98/98]	Time 0.0486	Data 0.0233	Loss 0.1243	Acc 95.57
# Test: [20/20]	Time 0.0892	Data 0.0798	Loss 0.5462	Acc 84.95
# Epoch: [75]
# Train: [98/98]	Time 0.0473	Data 0.0217	Loss 0.1164	Acc 95.92
# Test: [20/20]	Time 0.0899	Data 0.0803	Loss 0.5688	Acc 84.74
# Epoch: [76]
# Train: [98/98]	Time 0.0487	Data 0.0240	Loss 0.1061	Acc 96.29
# Test: [20/20]	Time 0.0907	Data 0.0814	Loss 0.5497	Acc 85.26
# Epoch: [77]
# Train: [98/98]	Time 0.0493	Data 0.0240	Loss 0.0970	Acc 96.68
# Test: [20/20]	Time 0.0905	Data 0.0809	Loss 0.5597	Acc 84.88
# Epoch: [78]
# Train: [98/98]	Time 0.0482	Data 0.0237	Loss 0.0956	Acc 96.70
# Test: [20/20]	Time 0.0900	Data 0.0804	Loss 0.5434	Acc 85.71
# Epoch: [79]
# Train: [98/98]	Time 0.0478	Data 0.0225	Loss 0.0858	Acc 97.03
# Test: [20/20]	Time 0.0901	Data 0.0803	Loss 0.5615	Acc 85.64
# Epoch: [80]
# Train: [98/98]	Time 0.0485	Data 0.0230	Loss 0.0803	Acc 97.23
# Test: [20/20]	Time 0.0898	Data 0.0801	Loss 0.5685	Acc 85.55
# Epoch: [81]
# Train: [98/98]	Time 0.0478	Data 0.0230	Loss 0.0720	Acc 97.52
# Test: [20/20]	Time 0.0884	Data 0.0787	Loss 0.5792	Acc 85.63
# Epoch: [82]
# Train: [98/98]	Time 0.0487	Data 0.0223	Loss 0.0683	Acc 97.65
# Test: [20/20]	Time 0.0885	Data 0.0787	Loss 0.5738	Acc 85.68
# Epoch: [83]
# Train: [98/98]	Time 0.0478	Data 0.0224	Loss 0.0635	Acc 97.82
# Test: [20/20]	Time 0.0898	Data 0.0803	Loss 0.5743	Acc 85.95
# Epoch: [84]
# Train: [98/98]	Time 0.0480	Data 0.0219	Loss 0.0594	Acc 98.01
# Test: [20/20]	Time 0.0886	Data 0.0789	Loss 0.5700	Acc 86.10
# Epoch: [85]
# Train: [98/98]	Time 0.0483	Data 0.0221	Loss 0.0540	Acc 98.16
# Test: [20/20]	Time 0.0907	Data 0.0810	Loss 0.5722	Acc 86.22
# Epoch: [86]
# Train: [98/98]	Time 0.0480	Data 0.0222	Loss 0.0510	Acc 98.30
# Test: [20/20]	Time 0.0908	Data 0.0813	Loss 0.5659	Acc 86.32
# Epoch: [87]
# Train: [98/98]	Time 0.0480	Data 0.0235	Loss 0.0481	Acc 98.36
# Test: [20/20]	Time 0.0901	Data 0.0804	Loss 0.5707	Acc 86.49
# Epoch: [88]
# Train: [98/98]	Time 0.0484	Data 0.0236	Loss 0.0457	Acc 98.46
# Test: [20/20]	Time 0.0892	Data 0.0796	Loss 0.5795	Acc 86.49
# Epoch: [89]
# Train: [98/98]	Time 0.0477	Data 0.0228	Loss 0.0412	Acc 98.62
# Test: [20/20]	Time 0.0880	Data 0.0784	Loss 0.5832	Acc 86.44
# Epoch: [90]
# Train: [98/98]	Time 0.0474	Data 0.0223	Loss 0.0397	Acc 98.73
# Test: [20/20]	Time 0.0878	Data 0.0780	Loss 0.5813	Acc 86.63
# Epoch: [91]
# Train: [98/98]	Time 0.0474	Data 0.0232	Loss 0.0385	Acc 98.71
# Test: [20/20]	Time 0.0906	Data 0.0808	Loss 0.5809	Acc 86.46
# Epoch: [92]
# Train: [98/98]	Time 0.0477	Data 0.0235	Loss 0.0348	Acc 98.88
# Test: [20/20]	Time 0.0878	Data 0.0782	Loss 0.5795	Acc 86.49
# Epoch: [93]
# Train: [98/98]	Time 0.0487	Data 0.0243	Loss 0.0344	Acc 98.96
# Test: [20/20]	Time 0.0887	Data 0.0789	Loss 0.5781	Acc 86.62
# Epoch: [94]
# Train: [98/98]	Time 0.0485	Data 0.0222	Loss 0.0314	Acc 98.99
# Test: [20/20]	Time 0.0896	Data 0.0801	Loss 0.5802	Acc 86.56
# Epoch: [95]
# Train: [98/98]	Time 0.0478	Data 0.0222	Loss 0.0319	Acc 98.94
# Test: [20/20]	Time 0.0919	Data 0.0820	Loss 0.5779	Acc 86.60
# Epoch: [96]
# Train: [98/98]	Time 0.0484	Data 0.0220	Loss 0.0308	Acc 99.05
# Test: [20/20]	Time 0.0871	Data 0.0776	Loss 0.5803	Acc 86.60
# Epoch: [97]
# Train: [98/98]	Time 0.0480	Data 0.0224	Loss 0.0297	Acc 99.08
# Test: [20/20]	Time 0.0891	Data 0.0797	Loss 0.5797	Acc 86.67
# Epoch: [98]
# Train: [98/98]	Time 0.0484	Data 0.0234	Loss 0.0312	Acc 99.05
# Test: [20/20]	Time 0.0897	Data 0.0801	Loss 0.5790	Acc 86.65
# Epoch: [99]
# Train: [98/98]	Time 0.0479	Data 0.0236	Loss 0.0316	Acc 98.98
# Test: [20/20]	Time 0.0884	Data 0.0789	Loss 0.5789	Acc 86.68
# Finished Training
