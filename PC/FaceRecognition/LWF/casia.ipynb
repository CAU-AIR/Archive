# %%
import torch
import random
import torchvision
import numpy as np
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torchvision import transforms
from sklearn.model_selection import train_test_split

from utils.util import get_image_list, dataset_list, PathDataset, PathDataset_v2, make_task

from avalanche.training.supervised import LwF
from avalanche.logging import InteractiveLogger, WandBLogger
from avalanche.benchmarks.generators import nc_benchmark
from avalanche.training.plugins import EvaluationPlugin
from avalanche.evaluation.metrics import ExperienceAccuracy, ExperienceLoss, ExperienceForgetting, ExperienceCPUUsage, ExperienceMaxGPU, ExperienceMaxRAM, ExperienceTime, EpochAccuracy

# %%
seed = 0
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
# torch.cuda.manual_seed_all(seed) # if use multi-GPU
cudnn.deterministic = True  # 연산 처리 속도 감소 -> 모델과 코드를 배포해야 하는 연구 후반 단계에 사용
cudnn.benchmark = False

# %%
data_path = "../Data/CASIA-WebFace/" 

dataset = get_image_list(data_path)
x_train, x_test, y_train, y_test = train_test_split(dataset[0], dataset[1], test_size=0.2, shuffle=True, random_state=seed, stratify=dataset[1])

train_set = dataset_list(x_train, y_train)
test_set = dataset_list(x_test, y_test)

print("train : ", len(y_train))
print("test : ", len(y_test))
# Out:
# train :  395531
# test :  98883

# %%
transforms_group = dict(
       train=(
       transforms.Compose(
              [
              transforms.ToTensor(),
              ]
       ),
       None,
       ),
       eval=(
       transforms.Compose(
              [
              transforms.ToTensor(),
              ]
       ),
       None,
       )
)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

num_class = 10575
incremental = 5
# train_task = make_task(incremental, y_train)
# test_task = make_task(incremental, y_test)

# train_set = PathDataset(train_set, transforms_group, "train", train_task)
# test_set = PathDataset(test_set, transforms_group, "eval", test_task)
train_set = PathDataset_v2(train_set, transforms_group, "train")
test_set = PathDataset_v2(test_set, transforms_group, "eval")

scenario = nc_benchmark(train_dataset=train_set,
                        test_dataset=test_set,
                        n_experiences=incremental,
                        task_labels=True,
                        seed=seed,
                        shuffle=False
                        )

model = torchvision.models.resnet18(pretrained=False, num_classes=num_class)
model.to(device)

optimizer = optim.SGD(model.parameters(), lr=1e-1)
criterion = torch.nn.CrossEntropyLoss()

# %%
interactive_logger = InteractiveLogger()
wandb_logger = WandBLogger(project_name="Face Recognition", run_name="GEM-CASIA-M10-E10")
eval_plugin = EvaluationPlugin(
    EpochAccuracy(),
    ExperienceAccuracy(),
    ExperienceLoss(),
    ExperienceForgetting(),
    ExperienceCPUUsage(),
    ExperienceMaxGPU(gpu_id=0),
    ExperienceMaxRAM(),
    ExperienceTime(),
    loggers=[interactive_logger, wandb_logger])
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: hopo55. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/home/cal-06/Desktop/Heonsung/Archive/PC/FaceRecognition/GEM/wandb/run-20220728_135358-33x633cy</code>
# Syncing run <strong><a href="https://wandb.ai/hopo55/Face%20Recognition/runs/33x633cy" target="_blank">GEM-CASIA-M200</a></strong> to <a href="https://wandb.ai/hopo55/Face%20Recognition" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# /home/cal-06/anaconda3/envs/hspark/lib/python3.8/site-packages/avalanche/training/plugins/evaluation.py:81: UserWarning: No benchmark provided to the evaluation plugin. Metrics may be computed on inconsistent portion of streams, use at your own risk.
#   warnings.warn(

# %% [markdown]
# ## GEM

# %%
train_batch = 10
eval_batch = 1
epoch = 10
memory_size = 10

strategies = GEM(model, optimizer, criterion, patterns_per_exp=memory_size, memory_strength=0.5, train_epochs=epoch, device=device, train_mb_size=train_batch, eval_mb_size=eval_batch, evaluator=eval_plugin)

# %%
print("Starting experiment...")
results = []
for experience in scenario.train_stream:
    print("Start training on experience ", experience.current_experience)
    strategies.train(experience)
    print("End training on experience ", experience.current_experience)
    print("Computing accuracy on the test set")
    results.append(strategies.eval(scenario.test_stream[:]))
# Out:
# Starting experiment...
# Start training on experience  0
# -- >> Start of training phase << --
# 100%|██████████| 11693/11693 [09:47<00:00, 19.89it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0285
# -- >> End of training phase << --
# End training on experience  0
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 29221/29221 [06:11<00:00, 78.59it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 525.4676
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 5.8297
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task000/Exp000 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 4671.2852
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 371.8229
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0687
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 20168/20168 [04:17<00:00, 78.20it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 499.6319
# 	Loss_Exp/eval_phase/test_stream/Task001/Exp001 = 14.0424
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task001/Exp001 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 4671.4258
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 257.8920
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19523/19523 [04:10<00:00, 78.04it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 493.7504
# 	Loss_Exp/eval_phase/test_stream/Task002/Exp002 = 14.3005
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task002/Exp002 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 4671.5156
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 250.1668
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 16313/16313 [03:29<00:00, 77.75it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 493.1661
# 	Loss_Exp/eval_phase/test_stream/Task003/Exp003 = 14.2858
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task003/Exp003 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 4671.6172
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 209.8076
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 13658/13658 [02:55<00:00, 77.81it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 492.3798
# 	Loss_Exp/eval_phase/test_stream/Task004/Exp004 = 14.0533
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task004/Exp004 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 4671.7148
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 175.5393
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# Start training on experience  1
# -- >> Start of training phase << --
# 100%|██████████| 8065/8065 [1:10:37<00:00,  1.90it/s]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task001 = 0.0861
# -- >> End of training phase << --
# End training on experience  1
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 29221/29221 [06:40<00:00, 73.04it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 461.5431
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0673
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 9.6293
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task000/Exp000 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 4814.9844
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 400.0538
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0014
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 20168/20168 [04:36<00:00, 72.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 460.7597
# 	Loss_Exp/eval_phase/test_stream/Task001/Exp001 = 5.6371
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task001/Exp001 = 40.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 4815.0117
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 276.5628
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0973
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19523/19523 [04:27<00:00, 73.10it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 461.3794
# 	Loss_Exp/eval_phase/test_stream/Task002/Exp002 = 14.0619
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task002/Exp002 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 4815.0391
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 267.0817
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 16313/16313 [03:44<00:00, 72.66it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 460.3527
# 	Loss_Exp/eval_phase/test_stream/Task003/Exp003 = 14.0031
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task003/Exp003 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 4815.0664
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 224.5149
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 13658/13658 [03:07<00:00, 72.90it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 460.9950
# 	Loss_Exp/eval_phase/test_stream/Task004/Exp004 = 13.7615
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task004/Exp004 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 4815.0898
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 187.3623
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# Start training on experience  2
# -- >> Start of training phase << --
# 100%|██████████| 7814/7814 [2:11:42<00:00,  1.01s/it]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task002 = 0.0888
# -- >> End of training phase << --
# End training on experience  2
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 29221/29221 [06:42<00:00, 72.58it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 462.4289
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0678
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 10.1314
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task000/Exp000 = 40.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 4961.5391
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 402.6112
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0009
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 20168/20168 [04:38<00:00, 72.29it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 461.5299
# 	ExperienceForgetting/eval_phase/test_stream/Task001/Exp001 = 0.0866
# 	Loss_Exp/eval_phase/test_stream/Task001/Exp001 = 8.2186
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task001/Exp001 = 38.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 4961.5391
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 278.9703
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0107
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19523/19523 [04:29<00:00, 72.55it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 462.7023
# 	Loss_Exp/eval_phase/test_stream/Task002/Exp002 = 5.1179
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task002/Exp002 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 4959.2891
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 269.0934
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.1481
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 16313/16313 [03:45<00:00, 72.20it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 461.7629
# 	Loss_Exp/eval_phase/test_stream/Task003/Exp003 = 13.4032
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task003/Exp003 = 40.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 4959.2891
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 225.9300
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 13658/13658 [03:09<00:00, 72.05it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 461.0739
# 	Loss_Exp/eval_phase/test_stream/Task004/Exp004 = 13.3012
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task004/Exp004 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 4959.2891
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 189.5597
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# Start training on experience  3
# -- >> Start of training phase << --
# 100%|██████████| 6516/6516 [2:47:32<00:00,  1.54s/it]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task003 = 0.0672
# -- >> End of training phase << --
# End training on experience  3
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 29221/29221 [06:46<00:00, 71.92it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 461.6523
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0686
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 10.9349
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task000/Exp000 = 40.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 5104.5625
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 406.3160
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0001
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 20168/20168 [04:39<00:00, 72.09it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 459.5047
# 	ExperienceForgetting/eval_phase/test_stream/Task001/Exp001 = 0.0956
# 	Loss_Exp/eval_phase/test_stream/Task001/Exp001 = 9.4848
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task001/Exp001 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 5104.5625
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 279.7754
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0017
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19523/19523 [04:33<00:00, 71.48it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 458.8873
# 	ExperienceForgetting/eval_phase/test_stream/Task002/Exp002 = 0.1336
# 	Loss_Exp/eval_phase/test_stream/Task002/Exp002 = 8.5892
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task002/Exp002 = 40.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 5104.5625
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 273.1369
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0145
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 16313/16313 [03:46<00:00, 72.04it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 461.6041
# 	Loss_Exp/eval_phase/test_stream/Task003/Exp003 = 5.6599
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task003/Exp003 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 5104.5625
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 226.4324
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0996
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 13658/13658 [03:09<00:00, 72.21it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 460.2383
# 	Loss_Exp/eval_phase/test_stream/Task004/Exp004 = 13.6498
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task004/Exp004 = 38.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 5104.5625
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 189.1523
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# Start training on experience  4
# -- >> Start of training phase << --
# 100%|██████████| 5468/5468 [3:03:55<00:00,  2.02s/it]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task004 = 0.0514
# -- >> End of training phase << --
# End training on experience  4
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 29221/29221 [06:48<00:00, 71.51it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 457.0773
# 	ExperienceForgetting/eval_phase/test_stream/Task000/Exp000 = 0.0681
# 	Loss_Exp/eval_phase/test_stream/Task000/Exp000 = 11.6000
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task000/Exp000 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 5245.5938
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 408.6556
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0006
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 20168/20168 [04:42<00:00, 71.34it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 455.9800
# 	ExperienceForgetting/eval_phase/test_stream/Task001/Exp001 = 0.0966
# 	Loss_Exp/eval_phase/test_stream/Task001/Exp001 = 10.2752
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task001/Exp001 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 5245.5938
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 282.6901
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0007
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 19523/19523 [04:33<00:00, 71.34it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 456.8442
# 	ExperienceForgetting/eval_phase/test_stream/Task002/Exp002 = 0.1440
# 	Loss_Exp/eval_phase/test_stream/Task002/Exp002 = 9.7591
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task002/Exp002 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 5245.5938
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 273.6513
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0041
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 16313/16313 [03:49<00:00, 71.19it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 456.6735
# 	ExperienceForgetting/eval_phase/test_stream/Task003/Exp003 = 0.0918
# 	Loss_Exp/eval_phase/test_stream/Task003/Exp003 = 9.3074
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task003/Exp003 = 38.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 5245.5938
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 229.1530
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0078
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 13658/13658 [03:11<00:00, 71.40it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 456.9601
# 	Loss_Exp/eval_phase/test_stream/Task004/Exp004 = 5.6988
# 	MaxGPU0Usage_Experience/eval_phase/test_stream/Task004/Exp004 = 39.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 5245.5938
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 191.2865
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0926
# -- >> End of eval phase << --
# [{'Top1_Acc_Epoch/train_phase/train_stream/Task000': 0.02851376084018952, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000': 0.06868348105814312, 'Loss_Exp/eval_phase/test_stream/Task000/Exp000': 5.829657632967204, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000': 525.4675735129881, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task000/Exp000': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000': 4671.28515625, 'Time_Exp/eval_phase/test_stream/Task000/Exp000': 371.822948948, 'Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001': 0.0, 'Loss_Exp/eval_phase/test_stream/Task001/Exp001': 14.042444728897092, 'CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001': 499.6318696880363, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task001/Exp001': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001': 4671.42578125, 'Time_Exp/eval_phase/test_stream/Task001/Exp001': 257.891966494004, 'Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002': 0.0, 'Loss_Exp/eval_phase/test_stream/Task002/Exp002': 14.300454784219996, 'CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002': 493.75041386117675, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task002/Exp002': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002': 4671.515625, 'Time_Exp/eval_phase/test_stream/Task002/Exp002': 250.1667908160016, 'Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003': 0.0, 'Loss_Exp/eval_phase/test_stream/Task003/Exp003': 14.285844925215322, 'CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003': 493.1661103626361, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task003/Exp003': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003': 4671.6171875, 'Time_Exp/eval_phase/test_stream/Task003/Exp003': 209.80764039499627, 'Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004': 0.0, 'Loss_Exp/eval_phase/test_stream/Task004/Exp004': 14.053259585818079, 'CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004': 492.37975951463517, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task004/Exp004': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004': 4671.71484375, 'Time_Exp/eval_phase/test_stream/Task004/Exp004': 175.53928551499848}, {'Top1_Acc_Epoch/train_phase/train_stream/Task000': 0.02851376084018952, 'Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000': 0.0014031005099072586, 'Loss_Exp/eval_phase/test_stream/Task000/Exp000': 9.629301317695768, 'CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000': 461.54307316295825, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task000/Exp000': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000': 4814.984375, 'Time_Exp/eval_phase/test_stream/Task000/Exp000': 400.0537534089963, 'Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001': 0.09733240777469258, 'Loss_Exp/eval_phase/test_stream/Task001/Exp001': 5.637135944728886, 'CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001': 460.7596734317064, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task001/Exp001': 40.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001': 4815.01171875, 'Time_Exp/eval_phase/test_stream/Task001/Exp001': 276.56283397899824, 'Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002': 0.0, 'Loss_Exp/eval_phase/test_stream/Task002/Exp002': 14.061851970950263, 'CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002': 461.3793631786396, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task002/Exp002': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002': 4815.0390625, 'Time_Exp/eval_phase/test_stream/Task002/Exp002': 267.0817396580096, 'Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003': 0.0, 'Loss_Exp/eval_phase/test_stream/Task003/Exp003': 14.00313759276863, 'CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003': 460.3526835155968, 'MaxGPU0Usage_Experience/eval_phase/test_stream/Task003/Exp003': 39.0, 'MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003': 4815.06640625, 'Time_Exp/eval_phase/test_stream/Task003/Exp003': 224.51486695000494, 'Top1_Acc_Exp/eval_ph ...
